# %% [markdown]
# ## Two sum.
# Given an array of integers `nums` and an integer `target`, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.

# %% [markdown]
# # Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
#
# # Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
#
# # Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]

# %% [markdown]
# Since I'm a troglodyte capable of only achieving O(n^n^n) time, lets code the trivial solution so I can at least get gears scraping.

# %% [markdown]
# (idk about having this jupyter lab setup btw, seems excessive.)

# %%
def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        for i in range(nums):
            for j in range()

# %% [markdown]
# Let's examine the optimal solution of O(n) to understand how to improve it
#
# def two_sum(nums, target):
#     # Dictionary to store {number: index}
#     seen = {}
#
#     for i, num in enumerate(nums):
#         # Calculate the required number to reach target
#         complement = target - num
#
#         # Check if the complement is already in the dictionary
#         if complement in seen:
#             return [seen[complement], i]
#
#         # Store current number and its index in the dictionary
#         seen[num] = i
#
#     return []
